# %%
import sys
# !conda install --yes --prefix {sys.prefix} ipywidgets
# !conda install --yes --prefix {sys.prefix} numpy
# !conda install --yes --prefix {sys.prefix} pandas
# !conda install --yes --prefix {sys.prefix} matplotlib
# !conda install --yes --prefix {sys.prefix} scipy
# !conda install --yes --prefix {sys.prefix} openpyxl
# !conda install --yes --prefix {sys.prefix} colorama
# !conda install --yes --prefix {sys.prefix} multiprocess -c conda-forge
# !conda install --yes --prefix {sys.prefix} -c conda-forge ipyfilechooser 
# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install ComponentDB-API
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jnudell\Miniconda3\envs\SharedMagnetShim
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following NEW packages will be INSTALLED:
#
#   ipywidgets         pkgs/main/noarch::ipywidgets-7.6.5-pyhd3eb1b0_1
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   widgetsnbextension pkgs/main/win-64::widgetsnbextension-3.5.2-py39haa95532_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jnudell\Miniconda3\envs\SharedMagnetShim
#
#   added / updated specs:
#     - numpy
# ...

# %% [markdown]
# ## Magnet Fiducial Transformation Program

# %% [markdown]
# ### Configurations
# Type in the following boxes the fiducial file and lattice file names, include the full path, and the destination directory.

# %%
import ipywidgets as widgets
import os, stat
import shutil

FiducialFileInput = widgets.Text(
    value='./SourceFiles/APS_U_MagnetFiducials_All.xlsx',
    placeholder='',
    description='Fiducial File name :',
    disabled=False,
    style={'description_width': 'initial'},
    layout = widgets.Layout(width='800px')
)

LatticeFileInput = widgets.Text(
    value='./SourceFiles/Lattice_June2021revision.xlsx',
    placeholder='',
    description='Lattice File name :',
    disabled=False,
    style={'description_width': 'initial'},
    layout = widgets.Layout(width='800px')
)

OutputDirectoryInput = widgets.Text(
    value='.',
    placeholder='',
    description='Output File Directory :',
    disabled=False,
    style={'description_width': 'initial'},
    layout = widgets.Layout(width='800px')
)

widgets.VBox([FiducialFileInput,LatticeFileInput,OutputDirectoryInput])
# Out:
# VBox(children=(Text(value='./SourceFiles/APS_U_MagnetFiducials_All.xlsx', description='Fiducial File name :', …

# %% [markdown]
# Run the following block and confirm the source files and the output directory.

# %%
FiducialFile=FiducialFileInput.value
LatticeFile=LatticeFileInput.value
OutputDirectory=OutputDirectoryInput.value
print(FiducialFile)
print(LatticeFile)
print(OutputDirectory)
# For internal use
ModuleDataDirectory = "./ModuleDataDirectory"
# Out:
# ./SourceFiles/APS_U_MagnetFiducials_All.xlsx
# ./SourceFiles/Lattice_June2021revision.xlsx
# .

# %% [markdown]
# ### Fetching the list of modules in the CDB
# If the user only wants the valid modules be put into the module dictionary, set the arguement of FindModulesInCDB "True". Otherwise, set it to "False"

# %%
# Execute this cell to fetch all defined magnet modules and magnet assignments in CDB
from PullModuleDataFromCDB import *
module_dict = FindModulesInCDB(True)
# Out:
#    NAME   CDB_ID QR_ID   # Magnets Assigned
# DLMA-1010 110357 31899         11
# DLMA-1020 110358 31890         11
# DLMA-1030 110359 31900         11
# DLMA-1040 110360 31901         11
# DLMA-1050 110361 31897         11
# DLMA-1100 110387 31893         11
# DLMA-1090 110397 31902         11
# DLMA-1140 129068 31894         11
# DLMA-1120 144065 31903         11
# DLMA-1160 161105 31904         11
# DLMA-1150 161772 31905         11
# DLMA-1060 166002 31906         11
# DLMA-1110 170038 31907         11
# DLMA-1170 172028 31908         11
# DLMA-1180 172481 31909         11
# DLMA-1070 174245 31910         11
# DLMA-1190 176162 31911         11
# DLMA-1080 176338 31912         11
# DLMA-1210 176581 31913         11
# DLMA-1230 176653 31914         11
# DLMA-1220 176659 31915         11
# DLMA-1200 189747 31916         11
# DLMA-1240 190518 31917         11
# DLMB-1010 110362 32234         11
# DLMB-1020 110363 32235         11
# DLMB-1030 110364 32236         11
# DLMB-1040 110365 31895         11
# DLMB-1050 110366 32237         11
# DLMB-1060 110367 32238         11
# DLMB-1070 110368 31892         11
# DLMB-1090 110396 31891         11
# DLMB-1100 115806 31896         11
# DLMB-1120 144081 32239         11
# DLMB-1080 144316 31898         11
# DLMB-1140 166001 32240         11
# DLMB-1150 166994 32241         11
# DLMB-1160 172347 32242         11
# DLMB-1170 173741 32243         11
# DLMB-1110 175628 32244         11
# DLMB-1180 176184 32245         11
# DLMB-1200 176219 32246         11
# DLMB-1190 176339 32247         11
# DLMB-1220 176902 32248         11
# DLMB-1230 189703 32249         11
# DLMB-1210 189727 32250         11
# FODO-1010 110372 None         6
# FODO-1020 110373 None         1
# FODO-1030 110374 None         1
# FODO-1040 110375 None         1
# FODO-1050 110376 None         1
# FODO-1230 190359 None         1
# FODO-1220 190360 None         1
# FODO-1210 190361 None         1
# FODO-1200 190362 None         1
# FODO-1080 190363 None         1
# FODO-1070 190365 None         1
# FODO-1120 190366 None         1
# FODO-1090 190367 None         1
# FODO-1060 190368 None         1
# FODO-1180 190369 None         1
# FODO-1150 190370 None         1
# FODO-1110 190371 None         1
# FODO-1140 190372 None         1
# FODO-1100 190373 None         1
# FODO-1130 190374 None         1
# FODO-1190 190375 None         1
# FODO-1160 190378 None         1
# FODO-1170 190379 None         1
# QMQA-1010 110377 32320         3
# QMQA-1020 110378 32321         0
# QMQA-1030 110379 32322         0
# QMQA-1040 110380 32323         0
# QMQA-1050 110381 32324         0
# QMQA-1060 190383 32325         0
# QMQA-1070 190384 32326         0
# QMQA-1080 190385 32327         0
# QMQA-1090 190386 32328         0
# QMQB-1010 110382 None         0
# QMQB-1020 110383 None         0
# QMQB-1030 110384 None         0
# QMQB-1040 110385 None         0
# QMQB-1050 110386 None         0

# %% [markdown]
# ### Selecting modules
# * Print out the content of the module ditionary and make sure it contains all modules the user wants.
# * Check the modules to be processed

# %%
# Execute this cell to list all the magnet modules found
print(module_dict)
# Create a checkbox list
module_sel = []
for name in module_dict.keys():
    module_sel.append(widgets.Checkbox(value=True,description=name,disabled=False,indent=True))

output = widgets.VBox(module_sel)
display(output)
# Out:
# {'DLMA-1010': 110357, 'DLMA-1020': 110358, 'DLMA-1030': 110359, 'DLMA-1040': 110360, 'DLMA-1050': 110361, 'DLMA-1100': 110387, 'DLMA-1090': 110397, 'DLMA-1140': 129068, 'DLMA-1120': 144065, 'DLMA-1160': 161105, 'DLMA-1150': 161772, 'DLMA-1060': 166002, 'DLMA-1110': 170038, 'DLMA-1170': 172028, 'DLMA-1180': 172481, 'DLMA-1070': 174245, 'DLMA-1190': 176162, 'DLMA-1080': 176338, 'DLMA-1210': 176581, 'DLMA-1230': 176653, 'DLMA-1220': 176659, 'DLMA-1200': 189747, 'DLMA-1240': 190518, 'DLMB-1010': 110362, 'DLMB-1020': 110363, 'DLMB-1030': 110364, 'DLMB-1040': 110365, 'DLMB-1050': 110366, 'DLMB-1060': 110367, 'DLMB-1070': 110368, 'DLMB-1090': 110396, 'DLMB-1100': 115806, 'DLMB-1120': 144081, 'DLMB-1080': 144316, 'DLMB-1140': 166001, 'DLMB-1150': 166994, 'DLMB-1160': 172347, 'DLMB-1170': 173741, 'DLMB-1110': 175628, 'DLMB-1180': 176184, 'DLMB-1200': 176219, 'DLMB-1190': 176339, 'DLMB-1220': 176902, 'DLMB-1230': 189703, 'DLMB-1210': 189727, 'FODO-1010': 110372, 'FODO-1020': 110373, 'FODO-1030': 110374, 'FODO-1040': 110375, 'FODO-1050': 110376, 'FODO-1230': 190359, 'FODO-1220': 190360, 'FODO-1210': 190361, 'FODO-1200': 190362, 'FODO-1080': 190363, 'FODO-1070': 190365, 'FODO-1120': 190366, 'FODO-1090': 190367, 'FODO-1060': 190368, 'FODO-1180': 190369, 'FODO-1150': 190370, 'FODO-1110': 190371, 'FODO-1140': 190372, 'FODO-1100': 190373, 'FODO-1130': 190374, 'FODO-1190': 190375, 'FODO-1160': 190378, 'FODO-1170': 190379, 'QMQA-1010': 110377}
# VBox(children=(Checkbox(value=True, description='DLMA-1010'), Checkbox(value=True, description='DLMA-1020'), C…

# %% [markdown]
# ### Create a csv file selected modules
# Run the following block to create an aux csv file for each selected module.

# %%
# Execute this cell to create a csv file for the above modules

module_names = []

for item in module_sel:
    if item.value==True:
        module_names.append(item.description)

# To overwrite the module_names, type in the module names by hand
# examples
# module_names = ["DLMA-1010","DLMB-1070","DLMB-1090"]

CreateModuleMagnetInfoCsv(module_dict, module_names)
# Out:
# DLMA-1010 QR_ID= 31899
# OutputFile:  ./ModuleDataDirectory/DLMA-1010/DLMA-1010.csv
#    DQ576 DQ576 A:Q5 Q5 Production Magnet 100015076
#    DQ117 DQ117 A:Q1 Q1 Production Magnet 100011017
#    DS1034 None A:S1 S1/S3 Production Magnet 100021034
#    SQ301 SQ301 A:Q3 Q3 Production Magnet 100013001
#    SQ250 SQ250 A:Q2 Q2 Production Magnet 100012050
#    DS1038 None A:S3 S1/S3 Production Magnet 100021038
#    DQ410 DQ410 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014010
#    ES2027 ES2027 A:S2 S2 Sextupole Magnet 100022027
#    001 001 A:DLMA:SUPP DLMA Support Assembly 31847
#    MFC036 MFC036 A:FC1 8-Pole Fast Corrector Production Magnet 100008036
#    DM134 DM134 A:M1 M1 Production Magnet 100001034
#    MFC037 MFC037 A:FC2 8-Pole Fast Corrector Production Magnet 100008037
#
# DLMA-1020 QR_ID= 31890
# OutputFile:  ./ModuleDataDirectory/DLMA-1020/DLMA-1020.csv
#    ES2015 ES2015 A:S2 S2 Sextupole Magnet 100022015
#    DQ573 DQ573 A:Q5 Q5 Production Magnet 100015073
#    SQ333 None A:Q3 Q3 Production Magnet 100013033
#    DS1039 None A:S1 S1/S3 Production Magnet 100021039
#    DQ167 DQ167 A:Q1 Q1 Production Magnet 100011067
#    MFC124 MFC124 A:FC2 8-Pole Fast Corrector Production Magnet 100008124
#    MFC122 MFC122 A:FC1 8-Pole Fast Corrector Production Magnet 100008122
#    DQ470 DQ470 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014070
#    DM128 DM128 A:M1 M1 Production Magnet 100001028
#    SQ225 SQ225 A:Q2 Q2 Production Magnet 100012025
#    DS1032 None A:S3 S1/S3 Production Magnet 100021032
#    002 002 A:DLMA:SUPP DLMA Support Assembly 31848
#
# DLMA-1030 QR_ID= 31900
# OutputFile:  ./ModuleDataDirectory/DLMA-1030/DLMA-1030.csv
#    DS1097 None A:S1 S1/S3 Production Magnet 100021097
#    MFC003 MFC003 A:FC2 8-Pole Fast Corrector Production Magnet 100008003
#    DQ558 DQ558 A:Q5 Q5 Production Magnet 100015058
#    MFC002 MFC002 A:FC1 8-Pole Fast Corrector Production Magnet 100008002
#    DQ445 DQ445 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014045
#    DQ180 DQ180 A:Q1 Q1 Production Magnet 100011080
#    DS1086 None A:S3 S1/S3 Production Magnet 100021086
#    SQ252 SQ252 A:Q2 Q2 Production Magnet 100012052
#    Unit: 0003 DLMA-03 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    ES2045 ES2045 A:S2 S2 Sextupole Magnet 100022045
#    SQ314 None A:Q3 Q3 Production Magnet 100013014
#    003 003 A:DLMA:SUPP DLMA Support Assembly 31849
#    DM141 DM141 A:M1 M1 Production Magnet 100001041
#
# DLMA-1040 QR_ID= 31901
# OutputFile:  ./ModuleDataDirectory/DLMA-1040/DLMA-1040.csv
#    DS1056 None A:S3 S1/S3 Production Magnet 100021056
#    MFC106 MFC106 A:FC2 8-Pole Fast Corrector Production Magnet 100008106
#    SQ360 None A:Q3 Q3 Production Magnet 100013060
#    DS1148 None A:S1 S1/S3 Production Magnet 100021148
#    SQ220 SQ220 A:Q2 Q2 Production Magnet 100012020
#    MFC110 MFC110 A:FC1 8-Pole Fast Corrector Production Magnet 100008110
#    ES2069 ES2069 A:S2 S2 Sextupole Magnet 100022069
#    DQ580 DQ580 A:Q5 Q5 Production Magnet 100015080
#    DQ482 DQ482 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014082
#    004 004 A:DLMA:SUPP DLMA Support Assembly 31850
#    Unit: 0004 DLMA-04 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ119 DQ119 A:Q1 Q1 Production Magnet 100011019
#    DM109 DM109 A:M1 M1 Production Magnet 100001009
#
# DLMA-1050 QR_ID= 31897
# OutputFile:  ./ModuleDataDirectory/DLMA-1050/DLMA-1050.csv
#    MFC072 MFC072 A:FC2 8-Pole Fast Corrector Production Magnet 100008072
#    005 005 A:DLMA:SUPP DLMA Support Assembly 31851
#    SQ216 SQ216 A:Q2 Q2 Production Magnet 100012016
#    ES2054 ES2054 A:S2 S2 Sextupole Magnet 100022054
#    DQ409 DQ409 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014009
#    SQ331 None A:Q3 Q3 Production Magnet 100013031
#    DS1114 None A:S3 S1/S3 Production Magnet 100021114
#    Unit: 0005 DLMA-05 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ568 DQ568 A:Q5 Q5 Production Magnet 100015068
#    MFC074 MFC074 A:FC1 8-Pole Fast Corrector Production Magnet 100008074
#    DQ106 DQ106 A:Q1 Q1 Production Magnet 100011006
#    DS1110 None A:S1 S1/S3 Production Magnet 100021110
#    DM106 DM106 A:M1 M1 Production Magnet 100001006
#
# DLMA-1100 QR_ID= 31893
# OutputFile:  ./ModuleDataDirectory/DLMA-1100/DLMA-1100.csv
#    SQ243 SQ243 A:Q2 Q2 Production Magnet 100012043
#    DQ507 DQ507 A:Q5 Q5 Production Magnet 100015007
#    ES2064 ES2064 A:S2 S2 Sextupole Magnet 100022064
#    DS1048 None A:S1 S1/S3 Production Magnet 100021048
#    Unit: 0010 DLMA-10 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DS1054 None A:S3 S1/S3 Production Magnet 100021054
#    DQ133 DQ133 A:Q1 Q1 Production Magnet 100011033
#    SQ372 None A:Q3 Q3 Production Magnet 100013072
#    MFC038 MFC038 A:FC1 8-Pole Fast Corrector Production Magnet 100008038
#    DQ415 DQ415 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014015
#    010 010 A:DLMA:SUPP DLMA Support Assembly 31856
#    DM120 DM120 A:M1 M1 Production Magnet 100001020
#    MFC006 MFC006 A:FC2 8-Pole Fast Corrector Production Magnet 100008006
#
# DLMA-1090 QR_ID= 31902
# OutputFile:  ./ModuleDataDirectory/DLMA-1090/DLMA-1090.csv
#    DQ446 DQ446 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014046
#    MFC067 MFC067 A:FC1 8-Pole Fast Corrector Production Magnet 100008067
#    DS1070 None A:S3 S1/S3 Production Magnet 100021070
#    ES2024 ES2024 A:S2 S2 Sextupole Magnet 100022024
#    SQ332 None A:Q3 Q3 Production Magnet 100013032
#    DM114 DM114 A:M1 M1 Production Magnet 100001014
#    SQ211 SQ211 A:Q2 Q2 Production Magnet 100012011
#    DQ148 DQ148 A:Q1 Q1 Production Magnet 100011048
#    DQ528 DQ528 A:Q5 Q5 Production Magnet 100015028
#    009 009 A:DLMA:SUPP DLMA Support Assembly 31855
#    MFC068 MFC068 A:FC2 8-Pole Fast Corrector Production Magnet 100008068
#    DS1063 None A:S1 S1/S3 Production Magnet 100021063
#
# DLMA-1140 QR_ID= 31894
# OutputFile:  ./ModuleDataDirectory/DLMA-1140/DLMA-1140.csv
#    ES2065 ES2065 A:S2 S2 Sextupole Magnet 100022065
#    Unit: 0014 DLMA-14 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ109 DQ109 A:Q1 Q1 Production Magnet 100011009
#    014 014 A:DLMA:SUPP DLMA Support Assembly 31860
#    SQ241 SQ241 A:Q2 Q2 Production Magnet 100012041
#    SQ317 None A:Q3 Q3 Production Magnet 100013017
#    DM105 DM105 A:M1 M1 Production Magnet 100001005
#    DQ402 DQ402 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014002
#    MFC073 MFC073 A:FC1 8-Pole Fast Corrector Production Magnet 100008073
#    DQ579 DQ579 A:Q5 Q5 Production Magnet 100015079
#    DS1116 None A:S3 S1/S3 Production Magnet 100021116
#    DS1119 None A:S1 S1/S3 Production Magnet 100021119
#    MFC075 MFC075 A:FC2 8-Pole Fast Corrector Production Magnet 100008075
#
# DLMA-1120 QR_ID= 31903
# OutputFile:  ./ModuleDataDirectory/DLMA-1120/DLMA-1120.csv
#    DM137 DM137 A:M1 M1 Production Magnet 100001037
#    Unit: 0012 DLMA-12 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    012 012 A:DLMA:SUPP DLMA Support Assembly 31858
#    SQ265 SQ265 A:Q2 Q2 Production Magnet 100012065
#    SQ311 None A:Q3 Q3 Production Magnet 100013011
#    DQ563 DQ563 A:Q5 Q5 Production Magnet 100015063
#    DS1112 None A:S1 S1/S3 Production Magnet 100021112
#    MFC139 MFC139 A:FC2 8-Pole Fast Corrector Production Magnet 100008139
#    DQ450 DQ450 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014050
#    MFC137 MFC137 A:FC1 8-Pole Fast Corrector Production Magnet 100008137
#    ES2044 ES2044 A:S2 S2 Sextupole Magnet 100022044
#    DS1107 None A:S3 S1/S3 Production Magnet 100021107
#    DQ175 DQ175 A:Q1 Q1 Production Magnet 100011075
#
# DLMA-1160 QR_ID= 31904
# OutputFile:  ./ModuleDataDirectory/DLMA-1160/DLMA-1160.csv
#    DQ569 DQ569 A:Q5 Q5 Production Magnet 100015069
#    MFC130 MFC130 A:FC1 8-Pole Fast Corrector Production Magnet 100008130
#    SQ215 SQ215 A:Q2 Q2 Production Magnet 100012015
#    SQ315 None A:Q3 Q3 Production Magnet 100013015
#    MFC107 MFC106 A:FC2 8-Pole Fast Corrector Production Magnet 100008107
#    DM127 DM127 A:M1 M1 Production Magnet 100001027
#    DS1113 None A:S3 S1/S3 Production Magnet 100021113
#    DQ478 DQ478 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014078
#    ES2077 ES2077 A:S2 S2 Sextupole Magnet 100022077
#    DS1150 None A:S1 S1/S3 Production Magnet 100021150
#    016 016 A:DLMA:SUPP DLMA Support Assembly 31862
#    DQ105 DQ105 A:Q1 Q1 Production Magnet 100011005
#
# DLMA-1150 QR_ID= 31905
# OutputFile:  ./ModuleDataDirectory/DLMA-1150/DLMA-1150.csv
#    SQ363 None A:Q3 Q3 Production Magnet 100013063
#    MFC109 MFC109 A:FC2 8-Pole Fast Corrector Production Magnet 100008109
#    DM130 DM130 A:M1 M1 Production Magnet 100001030
#    DS1149 None A:S1 S1/S3 Production Magnet 100021149
#    MFC108 MFC108 A:FC1 8-Pole Fast Corrector Production Magnet 100008108
#    ES2082 ES2082 A:S2 S2 Sextupole Magnet 100022082
#    SQ281 SQ281 A:Q2 Q2 Production Magnet 100012081
#    DQ479 DQ479 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014079
#    DS1044 None A:S3 S1/S3 Production Magnet 100021044
#    015 015 A:DLMA:SUPP DLMA Support Assembly 31861
#    DQ121 DQ121 A:Q1 Q1 Production Magnet 100011021
#    DQ578 DQ578 A:Q5 Q5 Production Magnet 100015078
#
# DLMA-1060 QR_ID= 31906
# OutputFile:  ./ModuleDataDirectory/DLMA-1060/DLMA-1060.csv
#    DQ480 DQ480 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014080
#    DS1037 None A:S3 S1/S3 Production Magnet 100021037
#    ES2030 ES2030 A:S2 S2 Sextupole Magnet 100022030
#    DQ120 DQ120 A:Q1 Q1 Production Magnet 100011020
#    MFC135 MFC135 A:FC1 8-Pole Fast Corrector Production Magnet 100008135
#    SQ224 SQ224 A:Q2 Q2 Production Magnet 100012024
#    SQ361 None A:Q3 Q3 Production Magnet 100013061
#    DM117 DM117 A:M1 M1 Production Magnet 100001017
#    MFC131 MFC131 A:FC2 8-Pole Fast Corrector Production Magnet 100008131
#    006 006 A:DLMA:SUPP DLMA Support Assembly 31852
#    DS1035 None A:S1 S1/S3 Production Magnet 100021035
#    DQ567 DQ567 A:Q5 Q5 Production Magnet 100015067
#
# DLMA-1110 QR_ID= 31907
# OutputFile:  ./ModuleDataDirectory/DLMA-1110/DLMA-1110.csv
#    SQ342 None A:Q3 Q3 Production Magnet 100013042
#    MFC063 MFC063 A:FC2 8-Pole Fast Corrector Production Magnet 100008063
#    ES2071 ES2071 A:S2 S2 Sextupole Magnet 100022071
#    DQ168 DQ168 A:Q1 Q1 Production Magnet 100011068
#    011 011 A:DLMA:SUPP DLMA Support Assembly 31857
#    DQ575 DQ575 A:Q5 Q5 Production Magnet 100015075
#    DS1117 None A:S1 S1/S3 Production Magnet 100021117
#    DS1118 None A:S3 S1/S3 Production Magnet 100021118
#    Unit: 0011 DLMA-11 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ458 DQ458 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014058
#    SQ269 SQ269 A:Q2 Q2 Production Magnet 100012069
#    MFC065 MFC065 A:FC1 8-Pole Fast Corrector Production Magnet 100008065
#    DM123 DM123 A:M1 M1 Production Magnet 100001023
#
# DLMA-1170 QR_ID= 31908
# OutputFile:  ./ModuleDataDirectory/DLMA-1170/DLMA-1170.csv
#    DQ143 DQ143 A:Q1 Q1 Production Magnet 100011043
#    MFC116 MFC116 A:FC2 8-Pole Fast Corrector Production Magnet 100008116
#    DQ473 DQ473 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014073
#    SQ271 SQ271 A:Q2 Q2 Production Magnet 100012071
#    ES2017 ES2017 A:S2 S2 Sextupole Magnet 100022017
#    017 017 A:DLMA:SUPP DLMA Support Assembly 31863
#    SQ343 None A:Q3 Q3 Production Magnet 100013043
#    DS1142 None A:S1 S1/S3 Production Magnet 100021142
#    MFC118 MFC118 A:FC1 8-Pole Fast Corrector Production Magnet 100008118
#    DQ523 DQ523 A:Q5 Q5 Production Magnet 100015023
#    DS1141 None A:S3 S1/S3 Production Magnet 100021141
#    DM131 DM131 A:M1 M1 Production Magnet 100001031
#
# DLMA-1180 QR_ID= 31909
# OutputFile:  ./ModuleDataDirectory/DLMA-1180/DLMA-1180.csv
#    DS1144 None A:S3 S1/S3 Production Magnet 100021144
#    DQ540 DQ540 A:Q5 Q5 Production Magnet 100015040
#    SQ341 None A:Q3 Q3 Production Magnet 100013041
#    SQ205 SQ205 A:Q2 Q2 Production Magnet 100012005
#    MFC117 MFC117 A:FC1 8-Pole Fast Corrector Production Magnet 100008117
#    DQ438 DQ438 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014038
#    MFC119 MFC119 A:FC2 8-Pole Fast Corrector Production Magnet 100008119
#    018 018 A:DLMA:SUPP DLMA Support Assembly 31864
#    DQ113 DQ113 A:Q1 Q1 Production Magnet 100011013
#    DS1145 None A:S1 S1/S3 Production Magnet 100021145
#    ES2081 ES2081 A:S2 S2 Sextupole Magnet 100022081
#    DM124 DM124 A:M1 M1 Production Magnet 100001024
#
# DLMA-1070 QR_ID= 31910
# OutputFile:  ./ModuleDataDirectory/DLMA-1070/DLMA-1070.csv
#    Unit: 0007 DLMA-07 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ559 DQ559 A:Q5 Q5 Production Magnet 100015059
#    DM135 DM135 A:M1 M1 Production Magnet 100001035
#    MFC136 MFC136 A:FC1 8-Pole Fast Corrector Production Magnet 100008136
#    SQ267 SQ267 A:Q2 Q2 Production Magnet 100012067
#    DS1108 None A:S3 S1/S3 Production Magnet 100021108
#    DS1111 None A:S1 S1/S3 Production Magnet 100021111
#    DQ179 DQ179 A:Q1 Q1 Production Magnet 100011079
#    SQ312 None A:Q3 Q3 Production Magnet 100013012
#    MFC140 MFC140 A:FC2 8-Pole Fast Corrector Production Magnet 100008140
#    ES2056 ES2056 A:S2 S2 Sextupole Magnet 100022056
#    007 007 A:DLMA:SUPP DLMA Support Assembly 31853
#    DQ456 DQ456 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014056
#
# DLMA-1190 QR_ID= 31911
# OutputFile:  ./ModuleDataDirectory/DLMA-1190/DLMA-1190.csv
#    SQ219 SQ219 A:Q2 Q2 Production Magnet 100012019
#    DM133 DM133 A:M1 M1 Production Magnet 100001033
#    DQ466 DQ466 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014066
#    MFC034 MFC034 A:FC2 8-Pole Fast Corrector Production Magnet 100008034
#    DS1157 None A:S1 S1/S3 Production Magnet 100021157
#    019 019 A:DLMA:SUPP DLMA Support Assembly 31865
#    ES2014 ES2014 A:S2 S2 Sextupole Magnet 100022014
#    Unit: 0019 DLMA-19 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ135 DQ135 A:Q1 Q1 Production Magnet 100011035
#    DS1152 None A:S3 S1/S3 Production Magnet 100021152
#    SQ359 None A:Q3 Q3 Production Magnet 100013059
#    MFC035 MFC035 A:FC1 8-Pole Fast Corrector Production Magnet 100008035
#    DQ519 DQ519 A:Q5 Q5 Production Magnet 100015019
#
# DLMA-1080 QR_ID= 31912
# OutputFile:  ./ModuleDataDirectory/DLMA-1080/DLMA-1080.csv
#    Unit: 0008 DLMA-08 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    MFC145 MFC145 A:FC1 8-Pole Fast Corrector Production Magnet 100008145
#    DQ516 DQ516 A:Q5 Q5 Production Magnet 100015016
#    DQ460 DQ460 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014060
#    SQ354 None A:Q3 Q3 Production Magnet 100013054
#    008 008 A:DLMA:SUPP DLMA Support Assembly 31854
#    DS1137 None A:S1 S1/S3 Production Magnet 100021137
#    MFC033 MFC033 A:FC2 8-Pole Fast Corrector Production Magnet 100008033
#    DS1156 None A:S3 S1/S3 Production Magnet 100021156
#    SQ208 SQ208 A:Q2 Q2 Production Magnet 100012008
#    ES2029 ES2029 A:S2 S2 Sextupole Magnet 100022029
#    DM139 DM139 A:M1 M1 Production Magnet 100001039
#    DQ144 DQ144 A:Q1 Q1 Production Magnet 100011044
#
# DLMA-1210 QR_ID= 31913
# OutputFile:  ./ModuleDataDirectory/DLMA-1210/DLMA-1210.csv
#    021 021 A:DLMA:SUPP DLMA Support Assembly 31867
#    SQ256 SQ256 A:Q2 Q2 Production Magnet 100012056
#    MFC097 MFC097 A:FC1 8-Pole Fast Corrector Production Magnet 100008097
#    Unit: 0021 DLMA-21 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    ES2047 ES2047 A:S2 S2 Sextupole Magnet 100022047
#    DS1084 None A:S1 S1/S3 Production Magnet 100021084
#    DQ158 DQ158 A:Q1 Q1 Production Magnet 100011058
#    MFC099 MFC099 A:FC2 8-Pole Fast Corrector Production Magnet 100008099
#    DQ463 DQ463 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014063
#    DM108 DM108 A:M1 M1 Production Magnet 100001008
#    DS1091 None A:S3 S1/S3 Production Magnet 100021091
#    SQ383 None A:Q3 Q3 Production Magnet 100013083
#    DQ518 DQ518 A:Q5 Q5 Production Magnet 100015018
#
# DLMA-1230 QR_ID= 31914
# OutputFile:  ./ModuleDataDirectory/DLMA-1230/DLMA-1230.csv
#    Unit: 0023 DLMA-23 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    ES2011 ES2011 A:S2 S2 Sextupole Magnet 100022011
#    023 023 A:DLMA:SUPP DLMA Support Assembly 31869
#    SQ242 SQ242 A:Q2 Q2 Production Magnet 100012042
#    DQ443 DQ443 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014043
#    DQ128 DQ128 A:Q1 Q1 Production Magnet 100011028
#    DS1075 None A:S1 S1/S3 Production Magnet 100021075
#    DM113 DM113 A:M1 M1 Production Magnet 100001013
#    DS1082 None A:S3 S1/S3 Production Magnet 100021082
#    MFC044 MFC044 A:FC2 8-Pole Fast Corrector Production Magnet 100008044
#    DQ565 DQ565 A:Q5 Q5 Production Magnet 100015065
#    SQ381 None A:Q3 Q3 Production Magnet 100013081
#    MFC042 MFC042 A:FC1 8-Pole Fast Corrector Production Magnet 100008042
#
# DLMA-1220 QR_ID= 31915
# OutputFile:  ./ModuleDataDirectory/DLMA-1220/DLMA-1220.csv
#    ES2059 ES2059 A:S2 S2 Sextupole Magnet 100022059
#    MFC043 MFC043 A:FC1 8-Pole Fast Corrector Production Magnet 100008043
#    SQ240 SQ240 A:Q2 Q2 Production Magnet 100012040
#    DQ517 DQ517 A:Q5 Q5 Production Magnet 100015017
#    MFC098 MFC098 A:FC2 8-Pole Fast Corrector Production Magnet 100008098
#    DQ146 DQ146 A:Q1 Q1 Production Magnet 100011046
#    DM136 DM136 A:M1 M1 Production Magnet 100001036
#    022 022 A:DLMA:SUPP DLMA Support Assembly 31868
#    Unit: 0022 DLMA-22 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    DQ451 DQ451 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014051
#    DS1078 None A:S1 S1/S3 Production Magnet 100021078
#    DS1092 None A:S3 S1/S3 Production Magnet 100021092
#    SQ367 None A:Q3 Q3 Production Magnet 100013067
#
# DLMA-1200 QR_ID= 31916
# OutputFile:  ./ModuleDataDirectory/DLMA-1200/DLMA-1200.csv
#    DQ136 DQ136 A:Q1 Q1 Production Magnet 100011036
#    MFC030 MFC030 A:FC1 8-Pole Fast Corrector Production Magnet 100008030
#    DS1007 DS1007 A:S1 S1/S3 Production Magnet 100021007
#    DQ562 DQ562 A:Q5 Q5 Production Magnet 100015062
#    SQ324 None A:Q3 Q3 Production Magnet 100013024
#    DS1094 None A:S3 S1/S3 Production Magnet 100021094
#    DQ439 DQ439 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014039
#    020 020 A:DLMA:SUPP DLMA Support Assembly 31866
#    MFC022 MFC022 A:FC2 8-Pole Fast Corrector Production Magnet 100008022
#    DM140 DM140 A:M1 M1 Production Magnet 100001040
#    Unit: 0020 DLMA-20 A:DLMA:BUSBAR DLM A BUS BAR ASSEMBLY None
#    SQ262 SQ262 A:Q2 Q2 Production Magnet 100012062
#    ES2050 ES2050 A:S2 S2 Sextupole Magnet 100022050
#
# DLMA-1240 QR_ID= 31917
# OutputFile:  ./ModuleDataDirectory/DLMA-1240/DLMA-1240.csv
#    ES2052 ES2052 A:S2 S2 Sextupole Magnet 100022052
#    MFC029 MFC029 A:FC2 8-Pole Fast Corrector Production Magnet 100008029
#    DQ182 DQ182 A:Q1 Q1 Production Magnet 100011082
#    DS1004 DS1004 A:S3 S1/S3 Production Magnet 100021004
#    MFC026 MFC026 A:FC1 8-Pole Fast Corrector Production Magnet 100008026
#    DS1009 DS1009 A:S1 S1/S3 Production Magnet 100021009
#    024 024 A:DLMA:SUPP DLMA Support Assembly 31870
#    DQ436 DQ436 A:Q4 Q4 Reverse Bend Quadrupole Magnet 100014036
#    SQ207 SQ207 A:Q2 Q2 Production Magnet 100012007
#    SQ366 None A:Q3 Q3 Production Magnet 100013066
#    DQ530 DQ530 A:Q5 Q5 Production Magnet 100015030
#    DM126 DM126 A:M1 M1 Production Magnet 100001026
#
# DLMB-1010 QR_ID= 32234
# OutputFile:  ./ModuleDataDirectory/DLMB-1010/DLMB-1010.csv
#    MFC125 MFC125 B:FC2 8-Pole Fast Corrector Production Magnet 100008125
#    SQ336 None B:Q3 Q3 Production Magnet 100013036
#    DQ163 DQ163 B:Q1 Q1 Production Magnet 100011063
#    DM175 DM175 B:M1 M1 Production Magnet 100001175
#    001 001 B:DLMB:SUPP DLMB Support Assembly 32535
#    DS1046 None B:S1 S1/S3 Production Magnet 100021046
#    ES2075 ES2075 B:S2 S2 Sextupole Magnet 100022075
#    SQ222 SQ222 B:Q2 Q2 Production Magnet 100012022
#    DQ462 DQ462 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014062
#    DQ572 DQ572 B:Q5 Q5 Production Magnet 100015072
#    DS1121 None B:S3 S1/S3 Production Magnet 100021121
#    MFC121 MFC121 B:FC1 8-Pole Fast Corrector Production Magnet 100008121
#
# DLMB-1020 QR_ID= 32235
# OutputFile:  ./ModuleDataDirectory/DLMB-1020/DLMB-1020.csv
#    DM162 DM162 B:M1 M1 Production Magnet 100001162
#    SQ321 None B:Q3 Q3 Production Magnet 100013021
#    002 002 B:DLMB:SUPP DLMB Support Assembly 32536
#    SQ204 SQ204 B:Q2 Q2 Production Magnet 100012004
#    DQ543 DQ543 B:Q5 Q5 Production Magnet 100015043
#    DS1093 None B:S1 S1/S3 Production Magnet 100021093
#    ES2066 ES2066 B:S2 S2 Sextupole Magnet 100022066
#    DQ453 DQ453 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014053
#    MFC008 MFC008 B:FC1 8-Pole Fast Corrector Production Magnet 100008008
#    DQ153 DQ153 B:Q1 Q1 Production Magnet 100011053
#    DS1102 None B:S3 S1/S3 Production Magnet 100021102
#    MFC009 MFC009 B:FC2 8-Pole Fast Corrector Production Magnet 100008009
#    Unit: 0002 DLMB-02 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#
# DLMB-1030 QR_ID= 32236
# OutputFile:  ./ModuleDataDirectory/DLMB-1030/DLMB-1030.csv
#    DQ522 DQ522 B:Q5 Q5 Production Magnet 100015022
#    ES2032 ES2032 B:S2 S2 Sextupole Magnet 100022032
#    Unit: 0003 DLMB-03 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DM166 DM166 B:M1 M1 Production Magnet 100001166
#    DQ176 DQ176 B:Q1 Q1 Production Magnet 100011076
#    DQ474 DQ474 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014074
#    DS1058 None B:S1 S1/S3 Production Magnet 100021058
#    003 003 B:DLMB:SUPP DLMB Support Assembly 32537
#    MFC066 MFC066 B:FC1 8-Pole Fast Corrector Production Magnet 100008066
#    SQ229 SQ229 B:Q2 Q2 Production Magnet 100012029
#    MFC069 MFC069 B:FC2 8-Pole Fast Corrector Production Magnet 100008069
#    DS1064 None B:S3 S1/S3 Production Magnet 100021064
#    SQ338 None B:Q3 Q3 Production Magnet 100013038
#
# DLMB-1040 QR_ID= 31895
# OutputFile:  ./ModuleDataDirectory/DLMB-1040/DLMB-1040.csv
#    004 004 B:DLMB:SUPP DLMB Support Assembly 32538
#    DQ418 DQ418 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014018
#    Unit: 0004 DLMB-04 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DQ503 DQ503 B:Q5 Q5 Production Magnet 100015003
#    DS1059 None B:S3 S1/S3 Production Magnet 100021059
#    DS1057 None B:S1 S1/S3 Production Magnet 100021057
#    MFC017 MFC017 B:FC1 8-Pole Fast Corrector Production Magnet 100008017
#    DQ169 DQ169 B:Q1 Q1 Production Magnet 100011069
#    SQ373 None B:Q3 Q3 Production Magnet 100013073
#    SQ237 SQ237 B:Q2 Q2 Production Magnet 100012037
#    ES2073 ES2073 B:S2 S2 Sextupole Magnet 100022073
#    MFC019 MFC019 B:FC2 8-Pole Fast Corrector Production Magnet 100008019
#    DM143 DM143 B:M1 M1 Production Magnet 100001143
#
# DLMB-1050 QR_ID= 32237
# OutputFile:  ./ModuleDataDirectory/DLMB-1050/DLMB-1050.csv
#    DS1089 None B:S3 S1/S3 Production Magnet 100021089
#    Unit: 0005 DLMB-05 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DS1087 None B:S1 S1/S3 Production Magnet 100021087
#    005 005 B:DLMB:SUPP DLMB Support Assembly 32539
#    ES2033 ES2033 B:S2 S2 Sextupole Magnet 100022033
#    SQ358 None B:Q3 Q3 Production Magnet 100013058
#    DQ574 DQ574 B:Q5 Q5 Production Magnet 100015074
#    DQ142 DQ142 B:Q1 Q1 Production Magnet 100011042
#    MFC100 MFC100 B:FC2 8-Pole Fast Corrector Production Magnet 100008100
#    MFC096 MFC096 B:FC1 8-Pole Fast Corrector Production Magnet 100008096
#    DM182 DM182 B:M1 M1 Production Magnet 100001182
#    SQ248 SQ248 B:Q2 Q2 Production Magnet 100012048
#    DQ467 DQ467 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014067
#
# DLMB-1060 QR_ID= 32238
# OutputFile:  ./ModuleDataDirectory/DLMB-1060/DLMB-1060.csv
#    MFC061 MFC061 B:FC2 8-Pole Fast Corrector Production Magnet 100008061
#    006 006 B:DLMB:SUPP DLMB Support Assembly 32540
#    ES2068 ES2068 B:S2 S2 Sextupole Magnet 100022068
#    DQ571 DQ571 B:Q5 Q5 Production Magnet 100015071
#    DQ152 DQ152 B:Q1 Q1 Production Magnet 100011052
#    DM174 DM174 B:M1 M1 Production Magnet 100001174
#    MFC062 MFC062 B:FC1 8-Pole Fast Corrector Production Magnet 100008062
#    DS1051 None B:S1 S1/S3 Production Magnet 100021051
#    SQ337 None B:Q3 Q3 Production Magnet 100013037
#    DQ471 DQ471 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014071
#    SQ238 SQ238 B:Q2 Q2 Production Magnet 100012038
#    DS1052 None B:S3 S1/S3 Production Magnet 100021052
#
# DLMB-1070 QR_ID= 31892
# OutputFile:  ./ModuleDataDirectory/DLMB-1070/DLMB-1070.csv
#    DS1055 None B:S3 S1/S3 Production Magnet 100021055
#    SQ221 SQ221 B:Q2 Q2 Production Magnet 100012021
#    DM150 DM150 B:M1 M1 Production Magnet 100001150
#    Unit: 0007 DLMB-07 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    007 007 B:DLMB:SUPP DLMB Support Assembly 32541
#    DQ512 DQ512 B:Q5 Q5 Production Magnet 100015012
#    ES2074 ES2074 B:S2 S2 Sextupole Magnet 100022074
#    DQ162 DQ162 B:Q1 Q1 Production Magnet 100011062
#    DS1053 None B:S1 S1/S3 Production Magnet 100021053
#    MFC040 MFC040 B:FC2 8-Pole Fast Corrector Production Magnet 100008040
#    MFC039 MFC039 B:FC1 8-Pole Fast Corrector Production Magnet 100008039
#    DQ416 DQ416 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014016
#    SQ370 None B:Q3 Q3 Production Magnet 100013070
#
# DLMB-1090 QR_ID= 31891
# OutputFile:  ./ModuleDataDirectory/DLMB-1090/DLMB-1090.csv
#    DM146 DM146 B:M1 M1 Production Magnet 100001146
#    DQ166 DQ166 B:Q1 Q1 Production Magnet 100011066
#    DS1061 None B:S3 S1/S3 Production Magnet 100021061
#    DQ506 DQ506 B:Q5 Q5 Production Magnet 100015006
#    Unit: 0009 DLMB-09 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    ES2034 ES2034 B:S2 S2 Sextupole Magnet 100022034
#    DS1047 None B:S1 S1/S3 Production Magnet 100021047
#    MFC005 MFC005 B:FC1 8-Pole Fast Corrector Production Magnet 100008005
#    SQ377 None B:Q3 Q3 Production Magnet 100013077
#    MFC007 MFC007 B:FC2 8-Pole Fast Corrector Production Magnet 100008007
#    DQ414 DQ414 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014014
#    009 009 B:DLMB:SUPP DLMB Support Assembly 32543
#    SQ209 SQ209 B:Q2 Q2 Production Magnet 100012009
#
# DLMB-1100 QR_ID= 31896
# OutputFile:  ./ModuleDataDirectory/DLMB-1100/DLMB-1100.csv
#    DS1060 None B:S1 S1/S3 Production Magnet 100021060
#    010 010 B:DLMB:SUPP DLMB Support Assembly 32544
#    SQ374 None B:Q3 Q3 Production Magnet 100013074
#    DM149 DM149 B:M1 M1 Production Magnet 100001149
#    DQ132 DQ132 B:Q1 Q1 Production Magnet 100011032
#    Unit: 0010 DLMB-10 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DQ505 DQ505 B:Q5 Q5 Production Magnet 100015005
#    DS1062 None B:S3 S1/S3 Production Magnet 100021062
#    DQ432 DQ432 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014032
#    MFC071 MFC071 B:FC2 8-Pole Fast Corrector Production Magnet 100008071
#    SQ247 SQ247 B:Q2 Q2 Production Magnet 100012047
#    MFC018 MFC018 B:FC1 8-Pole Fast Corrector Production Magnet 100008018
#    ES2078 ES2078 B:S2 S2 Sextupole Magnet 100022078
#
# DLMB-1120 QR_ID= 32239
# OutputFile:  ./ModuleDataDirectory/DLMB-1120/DLMB-1120.csv
#    MFC128 MFC128 B:FC2 8-Pole Fast Corrector Production Magnet 100008128
#    DQ102 DQ102 B:Q1 Q1 Production Magnet 100011002
#    MFC129 MFC129 B:FC1 8-Pole Fast Corrector Production Magnet 100008129
#    ES2055 ES2055 B:S2 S2 Sextupole Magnet 100022055
#    DQ425 DQ425 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014025
#    Unit: 0012 DLMB-12 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DS1151 None B:S3 S1/S3 Production Magnet 100021151
#    DS1120 None B:S1 S1/S3 Production Magnet 100021120
#    DQ582 DQ582 B:Q5 Q5 Production Magnet 100015082
#    012 012 B:DLMB:SUPP DLMB Support Assembly 32546
#    SQ244 SQ244 B:Q2 Q2 Production Magnet 100012044
#    DM158 DM158 B:M1 M1 Production Magnet 100001158
#    SQ316 None B:Q3 Q3 Production Magnet 100013016
#
# DLMB-1080 QR_ID= 31898
# OutputFile:  ./ModuleDataDirectory/DLMB-1080/DLMB-1080.csv
#    SQ318 None B:Q3 Q3 Production Magnet 100013018
#    MFC127 MFC127 B:FC2 8-Pole Fast Corrector Production Magnet 100008127
#    Unit: 0008 DLMB-08 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    MFC126 MFC126 B:FC1 8-Pole Fast Corrector Production Magnet 100008126
#    DQ581 DQ581 B:Q5 Q5 Production Magnet 100015081
#    DQ107 DQ107 B:Q1 Q1 Production Magnet 100011007
#    DM154 DM154 B:M1 M1 Production Magnet 100001154
#    008 008 B:DLMB:SUPP DLMB Support Assembly 32542
#    DQ442 DQ442 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014042
#    ES2043 ES2043 B:S2 S2 Sextupole Magnet 100022043
#    SQ231 SQ231 B:Q2 Q2 Production Magnet 100012031
#    DS1147 None B:S1 S1/S3 Production Magnet 100021147
#    DS1115 None B:S3 S1/S3 Production Magnet 100021115
#
# DLMB-1140 QR_ID= 32240
# OutputFile:  ./ModuleDataDirectory/DLMB-1140/DLMB-1140.csv
#    MFC132 MFC132 B:FC1 8-Pole Fast Corrector Production Magnet 100008132
#    014 014 B:DLMB:SUPP DLMB Support Assembly 32548
#    DQ531 DQ531 B:Q5 Q5 Production Magnet 100015031
#    ES2016 ES2016 B:S2 S2 Sextupole Magnet 100022016
#    SQ329 None B:Q3 Q3 Production Magnet 100013029
#    MFC134 MFC134 B:FC2 8-Pole Fast Corrector Production Magnet 100008134
#    DM157 DM157 B:M1 M1 Production Magnet 100001157
#    DS1041 None B:S1 S1/S3 Production Magnet 100021041
#    DQ165 DQ165 B:Q1 Q1 Production Magnet 100011065
#    DS1036 None B:S3 S1/S3 Production Magnet 100021036
#    SQ268 SQ268 B:Q2 Q2 Production Magnet 100012068
#    DQ472 DQ472 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014072
#
# DLMB-1150 QR_ID= 32241
# OutputFile:  ./ModuleDataDirectory/DLMB-1150/DLMB-1150.csv
#    SQ330 None B:Q3 Q3 Production Magnet 100013030
#    DM161 DM161 B:M1 M1 Production Magnet 100001161
#    DQ570 DQ570 B:Q5 Q5 Production Magnet 100015070
#    DQ164 DQ164 B:Q1 Q1 Production Magnet 100011064
#    MFC123 MFC123 B:FC1 8-Pole Fast Corrector Production Magnet 100008123
#    015 015 B:DLMB:SUPP DLMB Support Assembly 32549
#    ES2046 ES2046 B:S2 S2 Sextupole Magnet 100022046
#    MFC133 MFC133 B:FC2 8-Pole Fast Corrector Production Magnet 100008133
#    SQ212 SQ212 B:Q2 Q2 Production Magnet 100012012
#    DS1045 None B:S3 S1/S3 Production Magnet 100021045
#    DQ459 DQ459 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014059
#    DS1008 DS1008 B:S1 S1/S3 Production Magnet 100021008
#
# DLMB-1160 QR_ID= 32242
# OutputFile:  ./ModuleDataDirectory/DLMB-1160/DLMB-1160.csv
#    SQ213 SQ213 B:Q2 Q2 Production Magnet 100012013
#    DM179 DM179 B:M1 M1 Production Magnet 100001179
#    DQ524 DQ524 B:Q5 Q5 Production Magnet 100015024
#    MFC064 MFC064 B:FC2 8-Pole Fast Corrector Production Magnet 100008064
#    DQ465 DQ465 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014065
#    SQ339 None B:Q3 Q3 Production Magnet 100013039
#    DQ141 DQ141 B:Q1 Q1 Production Magnet 100011041
#    DS1049 None B:S1 S1/S3 Production Magnet 100021049
#    DS1050 None B:S3 S1/S3 Production Magnet 100021050
#    Unit: 0016 DLMB-16 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    016 016 B:DLMB:SUPP DLMB Support Assembly 32550
#    MFC120 MFC120 B:FC1 8-Pole Fast Corrector Production Magnet 100008120
#    ES2008 ES2008 B:S2 S2 Sextupole Magnet 100022008
#
# DLMB-1170 QR_ID= 32243
# OutputFile:  ./ModuleDataDirectory/DLMB-1170/DLMB-1170.csv
#    ES2080 ES2080 B:S2 S2 Sextupole Magnet 100022080
#    MFC010 MFC010 B:FC1 8-Pole Fast Corrector Production Magnet 100008010
#    DQ537 DQ537 B:Q5 Q5 Production Magnet 100015037
#    MFC011 MFC011 B:FC2 8-Pole Fast Corrector Production Magnet 100008011
#    SQ257 SQ257 B:Q2 Q2 Production Magnet 100012057
#    DQ452 DQ452 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014052
#    SQ335 None B:Q3 Q3 Production Magnet 100013035
#    DS1103 None B:S1 S1/S3 Production Magnet 100021103
#    Unit: 0017 DLMB-17 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    017 017 B:DLMB:SUPP DLMB Support Assembly 32551
#    DS1146 None B:S3 S1/S3 Production Magnet 100021146
#    DQ110 DQ110 B:Q1 Q1 Production Magnet 100011010
#    DM172 DM172 B:M1 M1 Production Magnet 100001172
#
# DLMB-1110 QR_ID= 32244
# OutputFile:  ./ModuleDataDirectory/DLMB-1110/DLMB-1110.csv
#    DS1069 None B:S3 S1/S3 Production Magnet 100021069
#    DQ174 DQ174 B:Q1 Q1 Production Magnet 100011074
#    ES2058 ES2058 B:S2 S2 Sextupole Magnet 100022058
#    DM171 DM171 B:M1 M1 Production Magnet 100001171
#    DQ481 DQ481 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014081
#    DQ557 DQ557 B:Q5 Q5 Production Magnet 100015057
#    DS1109 None B:S1 S1/S3 Production Magnet 100021109
#    MFC138 MFC138 B:FC2 8-Pole Fast Corrector Production Magnet 100008138
#    SQ313 None B:Q3 Q3 Production Magnet 100013013
#    Unit: 0011 DLMB-11 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    011 011 B:DLMB:SUPP DLMB Support Assembly 32545
#    MFC143 MFC143 B:FC1 8-Pole Fast Corrector Production Magnet 100008143
#    SQ277 SQ277 B:Q2 Q2 Production Magnet 100012077
#
# DLMB-1180 QR_ID= 32245
# OutputFile:  ./ModuleDataDirectory/DLMB-1180/DLMB-1180.csv
#    SQ327 None B:Q3 Q3 Production Magnet 100013027
#    DQ533 DQ533 B:Q5 Q5 Production Magnet 100015033
#    DQ140 DQ140 B:Q1 Q1 Production Magnet 100011040
#    DQ477 DQ477 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014077
#    Unit: 0018 DLMB-18 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DM165 DM165 B:M1 M1 Production Magnet 100001165
#    MFC070 MFC070 B:FC2 8-Pole Fast Corrector Production Magnet 100008070
#    MFC142 MFC142 B:FC1 8-Pole Fast Corrector Production Magnet 100008142
#    018 018 B:DLMB:SUPP DLMB Support Assembly 32552
#    ES2010 ES2010 B:S2 S2 Sextupole Magnet 100022010
#    DS1138 None B:S3 S1/S3 Production Magnet 100021138
#    DS1140 None B:S1 S1/S3 Production Magnet 100021140
#    SQ223 SQ223 B:Q2 Q2 Production Magnet 100012023
#
# DLMB-1200 QR_ID= 32246
# OutputFile:  ./ModuleDataDirectory/DLMB-1200/DLMB-1200.csv
#    DQ476 DQ476 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014076
#    DM144 DM144 B:M1 M1 Production Magnet 100001144
#    020 020 B:DLMB:SUPP DLMB Support Assembly 32554
#    MFC144 MFC144 B:FC1 8-Pole Fast Corrector Production Magnet 100008144
#    Unit: 0020 DLMB-20 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    MFC141 MFC141 B:FC2 8-Pole Fast Corrector Production Magnet 100008141
#    ES2040 ES2040 B:S2 S2 Sextupole Magnet 100022040
#    DQ130 DQ130 B:Q1 Q1 Production Magnet 100011030
#    SQ334 None B:Q3 Q3 Production Magnet 100013034
#    DS1143 None B:S3 S1/S3 Production Magnet 100021143
#    SQ255 SQ255 B:Q2 Q2 Production Magnet 100012055
#    DS1139 None B:S1 S1/S3 Production Magnet 100021139
#    DQ534 DQ534 B:Q5 Q5 Production Magnet 100015034
#
# DLMB-1190 QR_ID= 32247
# OutputFile:  ./ModuleDataDirectory/DLMB-1190/DLMB-1190.csv
#    DM148 DM148 B:M1 M1 Production Magnet 100001148
#    DQ147 DQ147 B:Q1 Q1 Production Magnet 100011047
#    ES2037 ES2037 B:S2 S2 Sextupole Magnet 100022037
#    DS1154 None B:S1 S1/S3 Production Magnet 100021154
#    SQ232 SQ232 B:Q2 Q2 Production Magnet 100012032
#    MFC032 MFC032 B:FC1 8-Pole Fast Corrector Production Magnet 100008032
#    MFC031 MFC031 B:FC2 8-Pole Fast Corrector Production Magnet 100008031
#    019 019 B:DLMB:SUPP DLMB Support Assembly 32553
#    SQ357 None B:Q3 Q3 Production Magnet 100013057
#    Unit: 0019 DLMB-19 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DQ532 DQ532 B:Q5 Q5 Production Magnet 100015032
#    DS1153 None B:S3 S1/S3 Production Magnet 100021153
#    DQ468 DQ468 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014068
#
# DLMB-1220 QR_ID= 32248
# OutputFile:  ./ModuleDataDirectory/DLMB-1220/DLMB-1220.csv
#    Unit: 0022 DLMB-22 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    ES2053 ES2053 B:S2 S2 Sextupole Magnet 100022053
#    DS1079 None B:S1 S1/S3 Production Magnet 100021079
#    SQ382 None B:Q3 Q3 Production Magnet 100013082
#    DS1081 None B:S3 S1/S3 Production Magnet 100021081
#    DQ566 DQ566 B:Q5 Q5 Production Magnet 100015066
#    DQ457 DQ457 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014057
#    022 022 B:DLMB:SUPP DLMB Support Assembly 32557
#    DM177 DM177 B:M1 M1 Production Magnet 100001177
#    SQ236 SQ236 B:Q2 Q2 Production Magnet 100012036
#    DQ129 DQ129 B:Q1 Q1 Production Magnet 100011029
#    MFC041 MFC041 B:FC1 8-Pole Fast Corrector Production Magnet 100008041
#    MFC045 MFC045 B:FC2 8-Pole Fast Corrector Production Magnet 100008045
#
# DLMB-1230 QR_ID= 32249
# OutputFile:  ./ModuleDataDirectory/DLMB-1230/DLMB-1230.csv
#    MFC024 MFC024 B:FC1 8-Pole Fast Corrector Production Magnet 100008024
#    DM173 DM173 B:M1 M1 Production Magnet 100001173
#    DS1096 None B:S1 S1/S3 Production Magnet 100021096
#    SQ325 None B:Q3 Q3 Production Magnet 100013025
#    DQ561 DQ561 B:Q5 Q5 Production Magnet 100015061
#    SQ259 SQ259 B:Q2 Q2 Production Magnet 100012059
#    DQ137 DQ137 B:Q1 Q1 Production Magnet 100011037
#    Unit: 0023 DLMB-23 B:DLMB:BUSBAR DLM B BUS BAR ASSEMBLY None
#    DQ444 DQ444 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014044
#    023 023 B:DLMB:SUPP DLMB Support Assembly 32556
#    DS1105 None B:S3 S1/S3 Production Magnet 100021105
#    MFC023 MFC023 B:FC2 8-Pole Fast Corrector Production Magnet 100008023
#    ES2039 ES2039 B:S2 S2 Sextupole Magnet 100022039
#
# DLMB-1210 QR_ID= 32250
# OutputFile:  ./ModuleDataDirectory/DLMB-1210/DLMB-1210.csv
#    SQ254 SQ254 B:Q2 Q2 Production Magnet 100012054
#    MFC021 MFC021 B:FC2 8-Pole Fast Corrector Production Magnet 100008021
#    DM176 DM176 B:M1 M1 Production Magnet 100001176
#    DQ564 DQ564 B:Q5 Q5 Production Magnet 100015064
#    MFC025 MFC025 B:FC1 8-Pole Fast Corrector Production Magnet 100008025
#    SQ319 None B:Q3 Q3 Production Magnet 100013019
#    DS1095 None B:S1 S1/S3 Production Magnet 100021095
#    021 021 B:DLMB:SUPP DLMB Support Assembly 32555
#    ES2060 ES2060 B:S2 S2 Sextupole Magnet 100022060
#    DQ461 DQ461 B:Q4 Q4 Reverse Bend Quadrupole Magnet 100014061
#    DQ127 DQ127 B:Q1 Q1 Production Magnet 100011027
#    DS1106 None B:S3 S1/S3 Production Magnet 100021106
#
# FODO-1010 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1010/FODO-1010.csv
#    TM409 TM409 A:M4 M4 Production Magnet 100004009
#    EQ803 EQ803 B:Q8 Q8 Production Magnet 100018003
#    001 001 FODO:SUPP FODO Support Assembly 32191
#    TM359 None B:M3 M3 Production Magnet 100003059
#    TM335 None A:M3 M3 Production Magnet 100003035
#    EQ804 EQ804 A:Q8 Q8 Production Magnet 100018004
#
# FODO-1020 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1020/FODO-1020.csv
#    002 002 FODO:SUPP FODO Support Assembly 32192
#
# FODO-1030 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1030/FODO-1030.csv
#    003 003 FODO:SUPP FODO Support Assembly 32193
#
# FODO-1040 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1040/FODO-1040.csv
#    004 004 FODO:SUPP FODO Support Assembly 32194
#
# FODO-1050 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1050/FODO-1050.csv
#    005 005 FODO:SUPP FODO Support Assembly 32195
#
# FODO-1230 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1230/FODO-1230.csv
#    023 023 FODO:SUPP FODO Support Assembly 32213
#
# FODO-1220 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1220/FODO-1220.csv
#    022 022 FODO:SUPP FODO Support Assembly 32212
#
# FODO-1210 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1210/FODO-1210.csv
#    021 021 FODO:SUPP FODO Support Assembly 32211
#
# FODO-1200 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1200/FODO-1200.csv
#    020 020 FODO:SUPP FODO Support Assembly 32210
#
# FODO-1080 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1080/FODO-1080.csv
#    008 008 FODO:SUPP FODO Support Assembly 32198
#
# FODO-1070 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1070/FODO-1070.csv
#    007 007 FODO:SUPP FODO Support Assembly 32197
#
# FODO-1120 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1120/FODO-1120.csv
#    012 012 FODO:SUPP FODO Support Assembly 32202
#
# FODO-1090 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1090/FODO-1090.csv
#    009 009 FODO:SUPP FODO Support Assembly 32199
#
# FODO-1060 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1060/FODO-1060.csv
#    006 006 FODO:SUPP FODO Support Assembly 32196
#
# FODO-1180 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1180/FODO-1180.csv
#    018 018 FODO:SUPP FODO Support Assembly 32208
#
# FODO-1150 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1150/FODO-1150.csv
#    015 015 FODO:SUPP FODO Support Assembly 32205
#
# FODO-1110 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-1110/FODO-1110.csv
#    011 011 FODO:SUPP FODO Support Assembly 32201
#
# FODO-1140 QR_ID= None
# OutputFile:  ./ModuleDataDirectory/FODO-
csv
# Write to OutputFile:  ./ModuleDataDirectory/FODO-1160/FD16_IdealCoordinates.csv
#
# Processing File:  ./ModuleDataDirectory/FODO-1170/FODO-1170.csv
# Write to OutputFile:  ./ModuleDataDirectory/FODO-1170/FD17_IdealCoordinates.csv

# %% [markdown]
# ## Copy output files to the "Output File Directory" specified by the user

# %%
for item in module_names:
    source = "./ModuleDataDirectory/"+item
    dest = OutputDirectory+"/"+item
    print(source,dest)
    #Uncomment the following line to remove the existing file before copying
    if os.path.exists(dest):
      shutil.rmtree(dest)
    shutil.copytree(source,dest)
# Out:
# ./ModuleDataDirectory/DLMA-1010 ./DLMA-1010
# ./ModuleDataDirectory/DLMA-1020 ./DLMA-1020
# ./ModuleDataDirectory/DLMA-1030 ./DLMA-1030
# ./ModuleDataDirectory/DLMA-1040 ./DLMA-1040
# ./ModuleDataDirectory/DLMA-1050 ./DLMA-1050
# ./ModuleDataDirectory/DLMA-1100 ./DLMA-1100
# ./ModuleDataDirectory/DLMA-1090 ./DLMA-1090
# ./ModuleDataDirectory/DLMA-1140 ./DLMA-1140
# ./ModuleDataDirectory/DLMA-1120 ./DLMA-1120
# ./ModuleDataDirectory/DLMA-1160 ./DLMA-1160
# ./ModuleDataDirectory/DLMA-1150 ./DLMA-1150
# ./ModuleDataDirectory/DLMA-1060 ./DLMA-1060
# ./ModuleDataDirectory/DLMA-1110 ./DLMA-1110
# ./ModuleDataDirectory/DLMA-1170 ./DLMA-1170
# ./ModuleDataDirectory/DLMA-1180 ./DLMA-1180
# ./ModuleDataDirectory/DLMA-1070 ./DLMA-1070
# ./ModuleDataDirectory/DLMA-1190 ./DLMA-1190
# ./ModuleDataDirectory/DLMA-1080 ./DLMA-1080
# ./ModuleDataDirectory/DLMA-1210 ./DLMA-1210
# ./ModuleDataDirectory/DLMA-1230 ./DLMA-1230
# ./ModuleDataDirectory/DLMA-1220 ./DLMA-1220
# ./ModuleDataDirectory/DLMB-1010 ./DLMB-1010
# ./ModuleDataDirectory/DLMB-1020 ./DLMB-1020
# ./ModuleDataDirectory/DLMB-1030 ./DLMB-1030
# ./ModuleDataDirectory/DLMB-1040 ./DLMB-1040
# ./ModuleDataDirectory/DLMB-1050 ./DLMB-1050
# ./ModuleDataDirectory/DLMB-1060 ./DLMB-1060
# ./ModuleDataDirectory/DLMB-1070 ./DLMB-1070
# ./ModuleDataDirectory/DLMB-1090 ./DLMB-1090
# ./ModuleDataDirectory/DLMB-1100 ./DLMB-1100
# ./ModuleDataDirectory/DLMB-1120 ./DLMB-1120
# ./ModuleDataDirectory/DLMB-1080 ./DLMB-1080
# ./ModuleDataDirectory/DLMB-1140 ./DLMB-1140
# ./ModuleDataDirectory/DLMB-1150 ./DLMB-1150
# ./ModuleDataDirectory/DLMB-1160 ./DLMB-1160
# ./ModuleDataDirectory/DLMB-1170 ./DLMB-1170
# ./ModuleDataDirectory/DLMB-1110 ./DLMB-1110
# ./ModuleDataDirectory/DLMB-1180 ./DLMB-1180
# ./ModuleDataDirectory/DLMB-1200 ./DLMB-1200
# ./ModuleDataDirectory/DLMB-1190 ./DLMB-1190
# ./ModuleDataDirectory/DLMB-1230 ./DLMB-1230
# ./ModuleDataDirectory/FODO-1010 ./FODO-1010
# ./ModuleDataDirectory/QMQA-1010 ./QMQA-1010
